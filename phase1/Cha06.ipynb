# %% [markdown]
# ## Cha06 数据加载、存储与文件格式

# %% [markdown]
# ### 6.1 读写文本格式的数据
# + 读取到的为 DataFrame 对象
# + read_csv 默认分隔符为逗号
# + read_table 默认分隔符为制表符

# %%
import pandas as pd
haitong = pd.read_csv('./haitong_test.csv',encoding='utf-8')
haitong.shape
# Out:
# (42182, 17)

# %%
haitong.index
# Out:
# RangeIndex(start=0, stop=42181, step=1)

# %%
haitong.dtypes
# Out:
# AeqO48ACEAdv                         object
# SH000001                             object
# CSSearch                             object
# 1.52814E+12                         float64
# 2018-5-28                            object
# 16                                    int64
# 1527497943                            int64
# 0b85cdb970fbc86847f6c4e4563845b2     object
# 8gop-omp1-cnf7-wthi                  object
# 68a02e775156861d6e9730804a7329d1     object
# 河南                                   object
# 信阳                                   object
# 9                                    object
# 5.06                                 object
# OPPO                                 object
# AOFOHBLJUAGQAHGM                     object
# android                              object
# Unnamed: 17                          object
# 172.190.12.160                       object
# brGCcqJMKctq                         object
# empty                                object
# ...

# %%
haitong.head()
# Out:
#    AeqO48ACEAdv  SH000001  CSSearch   1.52814E+12  2018-5-28  16  1527497943  \
# 0  AeqO48ACEAdv  SH601375  CSSearch  1.530420e+12  2018-5-28  16  1527497943
# 1  AeqO48ACEAdv  SH603017  CSSearch  1.531870e+12  2018-5-28  16  1527497943
# 2  AeqO48ACEAdv  SH603025  CSSearch  1.529800e+12  2018-5-28  16  1527497943
# 3  AeqO48ACEAdv  SH603116  CSSearch  1.531190e+12  2018-5-28  16  1527497943
# 4  AeqO48ACEAdv  SH603368  CSSearch  1.527930e+12  2018-5-28  16  1527497943
#
#    0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi  \
# 0  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
# 1  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
# 2  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
# 3  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
# 4  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
#
#    68a02e775156861d6e9730804a7329d1   ...     OPPO  AOFOHBLJUAGQAHGM  android  \
# ...

# %%
haitong.tail()
# Out:
#        AeqO48ACEAdv  SH000001  CSSearch   1.52814E+12  2018-5-28  16  \
# 42176  05kKOA6c120e  SH601021  CSSearch  1.528380e+12  2018-5-28  16
# 42177  05kKOA6c120e  SH601500  CSSearch  1.531520e+12  2018-5-28  16
# 42178  05kKOA6c120e  SH601811  CSSearch  1.530080e+12  2018-5-28  16
# 42179  05kKOA6c120e  SH601900  CSSearch  1.530100e+12  2018-5-28  16
# 42180  05kKOA6c120e  SH603159  CSSearch  1.531000e+12  2018-5-28  16
#
#        1527497943  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi  \
# 42176  1527495843  e3a9670174440d73bf1464fa86d5d204  r7bc-mjiu-qo7q-glkh
# 42177  1527495843  e3a9670174440d73bf1464fa86d5d204  r7bc-mjiu-qo7q-glkh
# 42178  1527495843  e3a9670174440d73bf1464fa86d5d204  r7bc-mjiu-qo7q-glkh
# 42179  1527495843  e3a9670174440d73bf1464fa86d5d204  r7bc-mjiu-qo7q-glkh
# 42180  1527495843  e3a9670174440d73bf1464fa86d5d204  r7bc-mjiu-qo7q-glkh
#
#        68a02e775156861d6e9730804a7329d1   ...    OPPO  AOFOHBLJUAGQAHGM  \
# ...

# %%
# 按行索引
haitong.loc[:1]

# haitong.loc[2:6]
# Out:
#    AeqO48ACEAdv  SH000001  CSSearch   1.52814E+12  2018-5-28  16  1527497943  \
# 0  AeqO48ACEAdv  SH601375  CSSearch  1.530420e+12  2018-5-28  16  1527497943
# 1  AeqO48ACEAdv  SH603017  CSSearch  1.531870e+12  2018-5-28  16  1527497943
#
#    0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi  \
# 0  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
# 1  0b85cdb970fbc86847f6c4e4563845b2  8gop-omp1-cnf7-wthi
#
#    68a02e775156861d6e9730804a7329d1   ...     OPPO  AOFOHBLJUAGQAHGM  android  \
# 0  68a02e775156861d6e9730804a7329d1   ...     OPPO  AOFOHBLJUAGQAHGM  android
# 1  68a02e775156861d6e9730804a7329d1   ...     OPPO  AOFOHBLJUAGQAHGM  android
#
#   Unnamed: 17  172.190.12.160  brGCcqJMKctq  empty android.1  5.01  480*854
# 0         NaN  172.190.12.160  brGCcqJMKctq  empty   android  5.01  480*854
# 1         NaN  172.190.12.160  brGCcqJMKctq  empty   android  5.01  480*854
#
# [2 rows x 24 columns]

# %%
haitong.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'G.1', 'K', 'L', 'M', 'N',
#        'O', 'P', 'Q'],
#       dtype='object')
